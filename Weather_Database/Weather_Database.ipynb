# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 727

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = str(city_weather["weather"][0]["description"])
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | belyy yar
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | college
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | vung tau
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | kalakamati
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | touros
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | sobolevo
# Processing Record 21 of Set 1 | benalla
# Processing Record 22 of Set 1 | rocha
# Processing Record 23 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 1 | araouane
# Processing Record 25 of Set 1 | bubaque
# Processing Record 26 of Set 1 | mahajanga
# Processing Record 27 of Set 1 | darhan
# Processing Record 28 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 1 | fairview
# Processing Record 30 of Set 1 | dawei
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | zabid
# Processing Record 33 of Set 1 | omboue
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | markova
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | shimoda
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | kunya
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | bambanglipuro
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | asau
# Processing Record 48 of Set 1 | mitsamiouli
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | farafangana
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | pimentel
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | hay river
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | kavaratti
# Processing Record 15 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 2 | acapulco
# Processing Record 18 of Set 2 | sundsvall
# Processing Record 19 of Set 2 | westport
# Processing Record 20 of Set 2 | elin pelin
# Processing Record 21 of Set 2 | la ronge
# Processing Record 22 of Set 2 | mar del plata
# Processing Record 23 of Set 2 | kawalu
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | port hedland
# Processing Record 26 of Set 2 | ponta delgada
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | phan thiet
# Processing Record 30 of Set 2 | vanavara
# Processing Record 31 of Set 2 | saint anthony
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | lulea
# Processing Record 35 of Set 2 | batemans bay
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | namatanai
# Processing Record 38 of Set 2 | athabasca
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | panacan
# Processing Record 42 of Set 2 | krasnoselkup
# Processing Record 43 of Set 2 | harrison
# Processing Record 44 of Set 2 | tevaitoa
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | tuatapere
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | guerrero negro
# Processing Record 50 of Set 2 | catio
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 3 | krasnoarmeysk
# Processing Record 4 of Set 3 | manavalakurichi
# Processing Record 5 of Set 3 | englewood
# Processing Record 6 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 3 | beringovskiy
# Processing Record 8 of Set 3 | clyde river
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | christchurch
# Processing Record 11 of Set 3 | mildura
# Processing Record 12 of Set 3 | cascais
# Processing Record 13 of Set 3 | mombasa
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | margate
# Processing Record 16 of Set 3 | anadyr
# Processing Record 17 of Set 3 | karlstad
# Processing Record 18 of Set 3 | rio grande
# Processing Record 19 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 3 | tasiilaq
# Processing Record 21 of Set 3 | ibaiti
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | narsaq
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | mwense
# Processing Record 27 of Set 3 | sembe
# Processing Record 28 of Set 3 | kenai
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | bibiani
# Processing Record 31 of Set 3 | kyabe
# Processing Record 32 of Set 3 | etchoropo
# Processing Record 33 of Set 3 | mogadishu
# Processing Record 34 of Set 3 | capreol
# Processing Record 35 of Set 3 | vestmanna
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | fortuna
# Processing Record 38 of Set 3 | dedza
# Processing Record 39 of Set 3 | emilio carranza
# Processing Record 40 of Set 3 | nome
# Processing Record 41 of Set 3 | aksu
# Processing Record 42 of Set 3 | port macquarie
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | los llanos de aridane
# Processing Record 45 of Set 3 | kirakira
# Processing Record 46 of Set 3 | busselton
# Processing Record 47 of Set 3 | partizanskoye
# Processing Record 48 of Set 3 | salinopolis
# Processing Record 49 of Set 3 | jega
# Processing Record 50 of Set 3 | nouakchott
# Processing Record 1 of Set 4 | berlevag
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 4 | cooma
# Processing Record 5 of Set 4 | lerwick
# Processing Record 6 of Set 4 | istok
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | ola
# Processing Record 9 of Set 4 | san francisco
# Processing Record 10 of Set 4 | narasannapeta
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | yerbogachen
# Processing Record 14 of Set 4 | meulaboh
# Processing Record 15 of Set 4 | katangli
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | honiara
# Processing Record 22 of Set 4 | peraiyur
# Processing Record 23 of Set 4 | acarau
# Processing Record 24 of Set 4 | xuddur
# Processing Record 25 of Set 4 | douentza
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 4 | boa vista
# Processing Record 29 of Set 4 | arlit
# Processing Record 30 of Set 4 | tilichiki
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | dongning
# Processing Record 33 of Set 4 | hilo
# Processing Record 34 of Set 4 | port hardy
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | dikson
# Processing Record 37 of Set 4 | zaozerne
# Processing Record 38 of Set 4 | jiangyin
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | japura
# Processing Record 41 of Set 4 | lethem
# Processing Record 42 of Set 4 | magadan
# Processing Record 43 of Set 4 | shinpokh
# Processing Record 44 of Set 4 | areosa
# Processing Record 45 of Set 4 | grand-santi
# Processing Record 46 of Set 4 | domzale
# Processing Record 47 of Set 4 | imbituba
# Processing Record 48 of Set 4 | hirara
# Processing Record 49 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 4 | mansa
# Processing Record 1 of Set 5 | caconda
# Processing Record 2 of Set 5 | auki
# Processing Record 3 of Set 5 | klaksvik
# Processing Record 4 of Set 5 | maumere
# Processing Record 5 of Set 5 | tazovskiy
# Processing Record 6 of Set 5 | port augusta
# Processing Record 7 of Set 5 | mishan
# Processing Record 8 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 5 | lavrentiya
# Processing Record 10 of Set 5 | olinda
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | morondava
# Processing Record 14 of Set 5 | nakamura
# Processing Record 15 of Set 5 | lake city
# Processing Record 16 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 5 | zlitan
# Processing Record 18 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 19 of Set 5 | dossor
# Processing Record 20 of Set 5 | tubuala
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 5 | manado
# Processing Record 24 of Set 5 | russellville
# Processing Record 25 of Set 5 | maceio
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | ancud
# Processing Record 29 of Set 5 | banda aceh
# Processing Record 30 of Set 5 | anloga
# Processing Record 31 of Set 5 | augustdorf
# Processing Record 32 of Set 5 | nabire
# Processing Record 33 of Set 5 | gamba
# Processing Record 34 of Set 5 | rawson
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | wiarton
# Processing Record 37 of Set 5 | teya
# Processing Record 38 of Set 5 | miranda
# Processing Record 39 of Set 5 | grand gaube
# Processing Record 40 of Set 5 | east london
# Processing Record 41 of Set 5 | mandalgovi
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | manadhoo
# Processing Record 44 of Set 5 | bria
# Processing Record 45 of Set 5 | labuan
# Processing Record 46 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 47 of Set 5 | komsomolskiy
# Processing Record 48 of Set 5 | muros
# Processing Record 49 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 5 | cabo san lucas
# Processing Record 1 of Set 6 | mayo
# Processing Record 2 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 6 | hami
# Processing Record 4 of Set 6 | chiang kham
# Processing Record 5 of Set 6 | avarua
# Processing Record 6 of Set 6 | niamey
# Processing Record 7 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 8 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 6 | cherskiy
# Processing Record 10 of Set 6 | yulara
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | kahului
# Processing Record 13 of Set 6 | bathsheba
# Processing Record 14 of Set 6 | codrington
# Processing Record 15 of Set 6 | axim
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | shar
# Processing Record 18 of Set 6 | shingu
# Processing Record 19 of Set 6 | aswan
# Processing Record 20 of Set 6 | porto velho
# Processing Record 21 of Set 6 | muli
# Processing Record 22 of Set 6 | pangnirtung
# Processing Record 23 of Set 6 | palakkodu
# Processing Record 24 of Set 6 | saint-paul
# Processing Record 25 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 6 | zinder
# Processing Record 27 of Set 6 | khor
# Processing Record 28 of Set 6 | kupang
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | isabela
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | mooi river
# City not found. Skipping...
# Processing Record 33 of Set 6 | jimenez
# Processing Record 34 of Set 6 | baoshan
# Processing Record 35 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 36 of Set 6 | tura
# Processing Record 37 of Set 6 | dingalan
# Processing Record 38 of Set 6 | vestmannaeyjar
# Processing Record 39 of Set 6 | novo oriente
# Processing Record 40 of Set 6 | solwezi
# Processing Record 41 of Set 6 | ilulissat
# Processing Record 42 of Set 6 | bairiki
# Processing Record 43 of Set 6 | hualmay
# Processing Record 44 of Set 6 | vardo
# Processing Record 45 of Set 6 | uyemskiy
# Processing Record 46 of Set 6 | marabba
# Processing Record 47 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 6 | djambala
# Processing Record 49 of Set 6 | yueyang
# Processing Record 50 of Set 6 | bull savanna
# Processing Record 1 of Set 7 | saldanha
# Processing Record 2 of Set 7 | husavik
# Processing Record 3 of Set 7 | xining
# Processing Record 4 of Set 7 | shadegan
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | te anau
# Processing Record 7 of Set 7 | cururupu
# Processing Record 8 of Set 7 | port keats
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | olafsvik
# Processing Record 11 of Set 7 | galle
# Processing Record 12 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 13 of Set 7 | kaitangata
# Processing Record 14 of Set 7 | luderitz
# Processing Record 15 of Set 7 | kasongo-lunda
# Processing Record 16 of Set 7 | tanout
# Processing Record 17 of Set 7 | shitanjing
# Processing Record 18 of Set 7 | sikonge
# Processing Record 19 of Set 7 | diamantino
# Processing Record 20 of Set 7 | saint-georges
# Processing Record 21 of Set 7 | gat
# Processing Record 22 of Set 7 | dejen
# Processing Record 23 of Set 7 | nalut
# Processing Record 24 of Set 7 | igrim
# Processing Record 25 of Set 7 | provideniya
# Processing Record 26 of Set 7 | itoman
# Processing Record 27 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 7 | macas
# Processing Record 29 of Set 7 | dimbokro
# Processing Record 30 of Set 7 | naze
# Processing Record 31 of Set 7 | tucupita
# Processing Record 32 of Set 7 | naryan-mar
# Processing Record 33 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 7 | brae
# Processing Record 35 of Set 7 | daru
# Processing Record 36 of Set 7 | newton
# Processing Record 37 of Set 7 | karachi
# Processing Record 38 of Set 7 | valenca
# Processing Record 39 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 7 | capoterra
# Processing Record 41 of Set 7 | trelew
# Processing Record 42 of Set 7 | kampene
# Processing Record 43 of Set 7 | bratsk
# Processing Record 44 of Set 7 | taitung
# Processing Record 45 of Set 7 | dungarvan
# Processing Record 46 of Set 7 | hamilton
# Processing Record 47 of Set 7 | maldonado
# Processing Record 48 of Set 7 | boende
# Processing Record 49 of Set 7 | loandjili
# Processing Record 50 of Set 7 | tupik
# Processing Record 1 of Set 8 | umm lajj
# Processing Record 2 of Set 8 | liling
# Processing Record 3 of Set 8 | majene
# Processing Record 4 of Set 8 | maragogi
# Processing Record 5 of Set 8 | mount isa
# Processing Record 6 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 8 | chalons-en-champagne
# Processing Record 8 of Set 8 | padang
# Processing Record 9 of Set 8 | jalu
# Processing Record 10 of Set 8 | marawi
# Processing Record 11 of Set 8 | fairbanks
# Processing Record 12 of Set 8 | palu
# Processing Record 13 of Set 8 | atar
# Processing Record 14 of Set 8 | zhigansk
# Processing Record 15 of Set 8 | paysandu
# Processing Record 16 of Set 8 | santa maria
# Processing Record 17 of Set 8 | port lincoln
# Processing Record 18 of Set 8 | eyl
# Processing Record 19 of Set 8 | kodiak
# Processing Record 20 of Set 8 | karmana
# City not found. Skipping...
# Processing Record 21 of Set 8 | benguela
# Processing Record 22 of Set 8 | bitung
# Processing Record 23 of Set 8 | aloleng
# Processing Record 24 of Set 8 | pahrump
# Processing Record 25 of Set 8 | luganville
# Processing Record 26 of Set 8 | ocampo
# Processing Record 27 of Set 8 | mehamn
# Processing Record 28 of Set 8 | pervouralsk
# Processing Record 29 of Set 8 | jardim
# Processing Record 30 of Set 8 | karatau
# Processing Record 31 of Set 8 | lokosovo
# Processing Record 32 of Set 8 | okha
# Processing Record 33 of Set 8 | sabang
# Processing Record 34 of Set 8 | saint-augustin
# Processing Record 35 of Set 8 | champerico
# Processing Record 36 of Set 8 | monreal
# Processing Record 37 of Set 8 | dolores
# Processing Record 38 of Set 8 | pocoes
# Processing Record 39 of Set 8 | tuyen quang
# Processing Record 40 of Set 8 | puerto colombia
# Processing Record 41 of Set 8 | richards bay
# Processing Record 42 of Set 8 | khasan
# Processing Record 43 of Set 8 | claveria
# Processing Record 44 of Set 8 | mao
# Processing Record 45 of Set 8 | marzuq
# Processing Record 46 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 8 | buckingham
# Processing Record 48 of Set 8 | weligama
# Processing Record 49 of Set 8 | havoysund
# Processing Record 50 of Set 8 | staryy krym
# Processing Record 1 of Set 9 | pochutla
# Processing Record 2 of Set 9 | nachingwea
# Processing Record 3 of Set 9 | ban nahin
# Processing Record 4 of Set 9 | pedra branca
# Processing Record 5 of Set 9 | saint-pierre
# Processing Record 6 of Set 9 | bachaquero
# Processing Record 7 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 9 | piracuruca
# Processing Record 9 of Set 9 | isla vista
# Processing Record 10 of Set 9 | balykshi
# Processing Record 11 of Set 9 | belmonte
# Processing Record 12 of Set 9 | davila
# Processing Record 13 of Set 9 | polewali
# Processing Record 14 of Set 9 | carahue
# Processing Record 15 of Set 9 | havre-saint-pierre
# Processing Record 16 of Set 9 | shache
# Processing Record 17 of Set 9 | willowmore
# Processing Record 18 of Set 9 | caravelas
# Processing Record 19 of Set 9 | nivala
# Processing Record 20 of Set 9 | adrar
# Processing Record 21 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 22 of Set 9 | dhidhdhoo
# Processing Record 23 of Set 9 | puerto baquerizo moreno
# Processing Record 24 of Set 9 | ponta do sol
# Processing Record 25 of Set 9 | nerchinskiy zavod
# Processing Record 26 of Set 9 | tucumcari
# Processing Record 27 of Set 9 | filadelfia
# Processing Record 28 of Set 9 | disna
# Processing Record 29 of Set 9 | ginir
# Processing Record 30 of Set 9 | puerto leguizamo
# Processing Record 31 of Set 9 | xichang
# Processing Record 32 of Set 9 | matamoros
# Processing Record 33 of Set 9 | hovd
# Processing Record 34 of Set 9 | general roca
# Processing Record 35 of Set 9 | kisangani
# Processing Record 36 of Set 9 | fort walton beach
# Processing Record 37 of Set 9 | idritsa
# Processing Record 38 of Set 9 | dunmore town
# Processing Record 39 of Set 9 | nantucket
# Processing Record 40 of Set 9 | katsuura
# Processing Record 41 of Set 9 | atasu
# Processing Record 42 of Set 9 | praia
# Processing Record 43 of Set 9 | cap malheureux
# Processing Record 44 of Set 9 | yuzhno-kurilsk
# Processing Record 45 of Set 9 | snyder
# Processing Record 46 of Set 9 | aksarka
# Processing Record 47 of Set 9 | zabol
# Processing Record 48 of Set 9 | babra
# Processing Record 49 of Set 9 | nuuk
# Processing Record 50 of Set 9 | yatou
# Processing Record 1 of Set 10 | taltal
# Processing Record 2 of Set 10 | anzio
# Processing Record 3 of Set 10 | lensk
# Processing Record 4 of Set 10 | sardarshahr
# Processing Record 5 of Set 10 | ayaviri
# Processing Record 6 of Set 10 | ugoofaaru
# Processing Record 7 of Set 10 | tual
# Processing Record 8 of Set 10 | thap than
# Processing Record 9 of Set 10 | matagami
# Processing Record 10 of Set 10 | srednekolymsk
# Processing Record 11 of Set 10 | cayenne
# Processing Record 12 of Set 10 | arman
# Processing Record 13 of Set 10 | kungalv
# Processing Record 14 of Set 10 | kamogawa
# Processing Record 15 of Set 10 | yenagoa
# Processing Record 16 of Set 10 | grahamstown
# Processing Record 17 of Set 10 | ulladulla
# Processing Record 18 of Set 10 | markapur
# Processing Record 19 of Set 10 | ichhawar
# Processing Record 20 of Set 10 | onega
# Processing Record 21 of Set 10 | luau
# Processing Record 22 of Set 10 | pocatello
# Processing Record 23 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 24 of Set 10 | geraldton
# Processing Record 25 of Set 10 | baykit
# Processing Record 26 of Set 10 | ereymentau
# Processing Record 27 of Set 10 | agadez
# Processing Record 28 of Set 10 | ust-maya
# Processing Record 29 of Set 10 | wanning
# Processing Record 30 of Set 10 | kiama
# Processing Record 31 of Set 10 | flinders
# Processing Record 32 of Set 10 | alugan
# Processing Record 33 of Set 10 | muroto
# Processing Record 34 of Set 10 | eureka
# Processing Record 35 of Set 10 | progreso
# Processing Record 36 of Set 10 | rodas
# Processing Record 37 of Set 10 | hearst
# Processing Record 38 of Set 10 | nazarovo
# Processing Record 39 of Set 10 | manokwari
# Processing Record 40 of Set 10 | ituverava
# Processing Record 41 of Set 10 | minbu
# Processing Record 42 of Set 10 | littleton
# Processing Record 43 of Set 10 | hailey
# Processing Record 44 of Set 10 | san jeronimo
# Processing Record 45 of Set 10 | da lat
# Processing Record 46 of Set 10 | aksay
# Processing Record 47 of Set 10 | am timan
# Processing Record 48 of Set 10 | angoram
# Processing Record 49 of Set 10 | xinzhi
# Processing Record 50 of Set 10 | gijon
# Processing Record 1 of Set 11 | manaure
# Processing Record 2 of Set 11 | san carlos de bariloche
# Processing Record 3 of Set 11 | mayskiy
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | sao joao da barra
# Processing Record 6 of Set 11 | salinas
# Processing Record 7 of Set 11 | smirnykh
# Processing Record 8 of Set 11 | kaeo
# Processing Record 9 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 11 | lasa
# Processing Record 11 of Set 11 | zaysan
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | tono
# Processing Record 14 of Set 11 | san cristobal
# Processing Record 15 of Set 11 | bogorodskoye
# Processing Record 16 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 11 | marystown
# Processing Record 18 of Set 11 | julio de castilhos
# Processing Record 19 of Set 11 | deputatskiy
# Processing Record 20 of Set 11 | oga
# Processing Record 21 of Set 11 | amahai
# Processing Record 22 of Set 11 | kasongo
# Processing Record 23 of Set 11 | orlik
# Processing Record 24 of Set 11 | robertson
# Processing Record 25 of Set 11 | norsup
# Processing Record 26 of Set 11 | ambon
# Processing Record 27 of Set 11 | amapa
# Processing Record 28 of Set 11 | deogarh
# Processing Record 29 of Set 11 | luwuk
# Processing Record 30 of Set 11 | honningsvag
# Processing Record 31 of Set 11 | culebra
# Processing Record 32 of Set 11 | oksovskiy
# Processing Record 33 of Set 11 | acaponeta
# Processing Record 34 of Set 11 | rapid valley
# Processing Record 35 of Set 11 | shamary
# Processing Record 36 of Set 11 | cartagena
# Processing Record 37 of Set 11 | livramento
# Processing Record 38 of Set 11 | roald
# Processing Record 39 of Set 11 | high level
# Processing Record 40 of Set 11 | thanh hoa
# Processing Record 41 of Set 11 | puri
# Processing Record 42 of Set 11 | lengshuijiang
# Processing Record 43 of Set 11 | hofn
# Processing Record 44 of Set 11 | khani
# Processing Record 45 of Set 11 | barinas
# Processing Record 46 of Set 11 | itarema
# Processing Record 47 of Set 11 | inongo
# Processing Record 48 of Set 11 | walvis bay
# Processing Record 49 of Set 11 | hervey bay
# Processing Record 50 of Set 11 | kilindoni
# Processing Record 1 of Set 12 | sisophon
# Processing Record 2 of Set 12 | santa engracia
# Processing Record 3 of Set 12 | port-gentil
# Processing Record 4 of Set 12 | san ignacio
# Processing Record 5 of Set 12 | gravdal
# Processing Record 6 of Set 12 | dakar
# Processing Record 7 of Set 12 | dawlatabad
# Processing Record 8 of Set 12 | enniskerry
# Processing Record 9 of Set 12 | chara
# Processing Record 10 of Set 12 | aklavik
# Processing Record 11 of Set 12 | bereda
# Processing Record 12 of Set 12 | madang
# Processing Record 13 of Set 12 | mount gambier
# Processing Record 14 of Set 12 | bonthe
# Processing Record 15 of Set 12 | pangoa
# Processing Record 16 of Set 12 | conceicao do araguaia
# Processing Record 17 of Set 12 | micheweni
# Processing Record 18 of Set 12 | taylors
# Processing Record 19 of Set 12 | gornyy
# Processing Record 20 of Set 12 | ouegoa
# Processing Record 21 of Set 12 | rio gallegos
# Processing Record 22 of Set 12 | bardiyah
# Processing Record 23 of Set 12 | falmouth
# Processing Record 24 of Set 12 | necochea
# Processing Record 25 of Set 12 | kita
# Processing Record 26 of Set 12 | campos novos
# Processing Record 27 of Set 12 | kargasok
# Processing Record 28 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 29 of Set 12 | ust-nera
# Processing Record 30 of Set 12 | udachnyy
# Processing Record 31 of Set 12 | vasudevanallur
# Processing Record 32 of Set 12 | fethiye
# Processing Record 33 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 34 of Set 12 | taldan
# Processing Record 35 of Set 12 | ambulu
# Processing Record 36 of Set 12 | isla mujeres
# Processing Record 37 of Set 12 | gzhatsk
# City not found. Skipping...
# Processing Record 38 of Set 12 | canyon lake
# Processing Record 39 of Set 12 | tamandare
# Processing Record 40 of Set 12 | san lorenzo
# Processing Record 41 of Set 12 | tall kayf
# Processing Record 42 of Set 12 | ariquemes
# Processing Record 43 of Set 12 | antofagasta
# Processing Record 44 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 12 | pombia
# Processing Record 46 of Set 12 | vostok
# Processing Record 47 of Set 12 | lakes entrance
# Processing Record 48 of Set 12 | pontianak
# Processing Record 49 of Set 12 | sola
# Processing Record 50 of Set 12 | mpika
# Processing Record 1 of Set 13 | muravlenko
# Processing Record 2 of Set 13 | kangundo
# Processing Record 3 of Set 13 | shelburne
# Processing Record 4 of Set 13 | leningradskiy
# Processing Record 5 of Set 13 | kisaran
# Processing Record 6 of Set 13 | smithers
# Processing Record 7 of Set 13 | skjervoy
# Processing Record 8 of Set 13 | gigmoto
# Processing Record 9 of Set 13 | yar-sale
# Processing Record 10 of Set 13 | nesebar
# Processing Record 11 of Set 13 | vieux-habitants
# Processing Record 12 of Set 13 | pak phanang
# Processing Record 13 of Set 13 | liverpool
# Processing Record 14 of Set 13 | sassandra
# Processing Record 15 of Set 13 | peleduy
# Processing Record 16 of Set 13 | quatre cocos
# Processing Record 17 of Set 13 | broome
# Processing Record 18 of Set 13 | pec
# Processing Record 19 of Set 13 | calabar
# Processing Record 20 of Set 13 | aosta
# Processing Record 21 of Set 13 | flin flon
# Processing Record 22 of Set 13 | ambilobe
# Processing Record 23 of Set 13 | dalianwan
# Processing Record 24 of Set 13 | sistranda
# Processing Record 25 of Set 13 | mabaruma
# Processing Record 26 of Set 13 | parkes
# Processing Record 27 of Set 13 | beloha
# Processing Record 28 of Set 13 | opuwo
# Processing Record 29 of Set 13 | kopervik
# Processing Record 30 of Set 13 | lingyuan
# Processing Record 31 of Set 13 | esil
# Processing Record 32 of Set 13 | great falls
# Processing Record 33 of Set 13 | denpasar
# Processing Record 34 of Set 13 | santa vitoria do palmar
# Processing Record 35 of Set 13 | ust-tsilma
# Processing Record 36 of Set 13 | fort nelson
# Processing Record 37 of Set 13 | nagyszenas
# Processing Record 38 of Set 13 | tallahassee
# Processing Record 39 of Set 13 | chumikan
# Processing Record 40 of Set 13 | rundu
# Processing Record 41 of Set 13 | saint peter
# Processing Record 42 of Set 13 | manta
# Processing Record 43 of Set 13 | isangel
# Processing Record 44 of Set 13 | blagoveshchensk
# Processing Record 45 of Set 13 | narrabri
# Processing Record 46 of Set 13 | moranbah
# Processing Record 47 of Set 13 | gobabis
# Processing Record 48 of Set 13 | pemangkat
# Processing Record 49 of Set 13 | teseney
# Processing Record 50 of Set 13 | nouadhibou
# Processing Record 1 of Set 14 | belaya kholunitsa
# Processing Record 2 of Set 14 | ostrovnoy
# Processing Record 3 of Set 14 | alken
# Processing Record 4 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 14 | marsh harbour
# Processing Record 6 of Set 14 | tulcingo
# City not found. Skipping...
# Processing Record 7 of Set 14 | kang
# Processing Record 8 of Set 14 | bathurst
# Processing Record 9 of Set 14 | bayanday
# Processing Record 10 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 14 | faya
# Processing Record 12 of Set 14 | sur
# Processing Record 13 of Set 14 | ondangwa
# Processing Record 14 of Set 14 | sidi ali
# Processing Record 15 of Set 14 | butte
# Processing Record 16 of Set 14 | nunkini
# Processing Record 17 of Set 14 | kurilsk
# Processing Record 18 of Set 14 | alyangula
# Processing Record 19 of Set 14 | kushmurun
# Processing Record 20 of Set 14 | uruzgan
# Processing Record 21 of Set 14 | ixtapa
# Processing Record 22 of Set 14 | zambezi
# Processing Record 23 of Set 14 | carazinho
# Processing Record 24 of Set 14 | mbouda
# Processing Record 25 of Set 14 | neiafu
# Processing Record 26 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 14 | yumen
# Processing Record 28 of Set 14 | mulege
# Processing Record 29 of Set 14 | black river
# Processing Record 30 of Set 14 | ferkessedougou
# Processing Record 31 of Set 14 | durban
# Processing Record 32 of Set 14 | carutapera
# Processing Record 33 of Set 14 | coquimbo
# Processing Record 34 of Set 14 | fukue
# Processing Record 35 of Set 14 | peniche
# Processing Record 36 of Set 14 | kloulklubed
# Processing Record 37 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 14 | morbegno
# Processing Record 39 of Set 14 | vega de alatorre
# Processing Record 40 of Set 14 | ust-koksa
# Processing Record 41 of Set 14 | itupiranga
# Processing Record 42 of Set 14 | joshimath
# Processing Record 43 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 44 of Set 14 | akhmeta
# Processing Record 45 of Set 14 | verkhnevilyuysk
# Processing Record 46 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 14 | bajram curri
# Processing Record 48 of Set 14 | narsimhapur
# Processing Record 49 of Set 14 | glassboro
# Processing Record 50 of Set 14 | diapaga
# Processing Record 1 of Set 15 | san quintin
# Processing Record 2 of Set 15 | solnechnyy
# Processing Record 3 of Set 15 | hue
# Processing Record 4 of Set 15 | turgenevo
# Processing Record 5 of Set 15 | orcopampa
# Processing Record 6 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 15 | lindi
# Processing Record 8 of Set 15 | dingtao
# Processing Record 9 of Set 15 | antalaha
# Processing Record 10 of Set 15 | ajdabiya
# Processing Record 11 of Set 15 | hammerfest
# Processing Record 12 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 15 | bozoum
# Processing Record 14 of Set 15 | macklin
# Processing Record 15 of Set 15 | koindu
# Processing Record 16 of Set 15 | mafinga
# Processing Record 17 of Set 15 | humaita
# Processing Record 18 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 15 | cape girardeau
# Processing Record 20 of Set 15 | talara
# Processing Record 21 of Set 15 | leshukonskoye
# Processing Record 22 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 15 | riyadh
# Processing Record 24 of Set 15 | velyka mykhaylivka
# Processing Record 25 of Set 15 | dingle
# Processing Record 26 of Set 15 | nemuro
# Processing Record 27 of Set 15 | canto do buriti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 672

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Belyy Yar  53.6039   91.3903     40.89        60           0
# 1    Bredasdorp -34.5322   20.0403     49.51        78          53
# 2       Ushuaia -54.8000  -68.3000     42.46        87           0
# 3       Rikitea -23.1203 -134.9692     70.32        61          91
# 4       Mataura -46.1927  168.8643     37.47        87          98
# 5   Yellowknife  62.4560 -114.3525     32.56        69         100
# 6    Georgetown   5.4112  100.3354     85.89        75          20
# 7       College  64.8569 -147.8028     44.98        72          75
# 8  Kruisfontein -34.0033   24.7314     54.88        80           9
# 9      Vung Tau  10.3460  107.0843     84.40        74          98
#
#    Wind Speed Country           Description
# 0        4.47      RU             clear sky
# 1        4.79      ZA         broken clouds
# 2       11.50      AR             clear sky
# 3       23.91      PF       overcast clouds
# 4       11.63      NZ            light rain
# 5        9.22      CA       overcast clouds
# 6        8.05      MY            few clouds
# 7        3.44      US         broken clouds
# 8        5.03      ZA             clear sky
# 9       17.47      VN  heavy intensity rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Belyy Yar      RU  53.6039   91.3903     40.89        60           0
# 1    Bredasdorp      ZA -34.5322   20.0403     49.51        78          53
# 2       Ushuaia      AR -54.8000  -68.3000     42.46        87           0
# 3       Rikitea      PF -23.1203 -134.9692     70.32        61          91
# 4       Mataura      NZ -46.1927  168.8643     37.47        87          98
# 5   Yellowknife      CA  62.4560 -114.3525     32.56        69         100
# 6    Georgetown      MY   5.4112  100.3354     85.89        75          20
# 7       College      US  64.8569 -147.8028     44.98        72          75
# 8  Kruisfontein      ZA -34.0033   24.7314     54.88        80           9
# 9      Vung Tau      VN  10.3460  107.0843     84.40        74          98
#
#    Wind Speed           Description
# 0        4.47             clear sky
# 1        4.79         broken clouds
# 2       11.50             clear sky
# 3       23.91       overcast clouds
# 4       11.63            light rain
# 5        9.22       overcast clouds
# 6        8.05            few clouds
# 7        3.44         broken clouds
# 8        5.03             clear sky
# 9       17.47  heavy intensity rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
